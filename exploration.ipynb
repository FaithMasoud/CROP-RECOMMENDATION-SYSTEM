# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

print("pandas version:", pd.__version__)
print("numpy version:", np.__version__)
print("scikit-learn version:", sklearn.__version__)
print("All systems go! ✅")
# Out:
# pandas version: 3.0.2
# numpy version: 2.4.4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 from sklearn.ensemble import RandomForestClassifier
#       6
#       7 print("pandas version:", pd.__version__)
#       8 print("numpy version:", np.__version__)
# ----> 9 print("scikit-learn version:", sklearn.__version__)
#      10 print("All systems go! ✅")
#
# NameError: name 'sklearn' is not defined

# %%
# Import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn                                        # ← ADD this line
from sklearn.ensemble import RandomForestClassifier   # ← keep this too

# Print versions to verify installation
print("pandas version:", pd.__version__)
print("numpy version:", np.__version__)
print("scikit-learn version:", sklearn.__version__)   # ← now this works
print("All systems go! ✅")
# Out:
# pandas version: 3.0.2
# numpy version: 2.4.4
# scikit-learn version: 1.8.0
# All systems go! ✅

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       8 import matplotlib.pyplot as plt    # base plotting library
#       9 import seaborn as sns              # beautiful statistical plots
#      10
#      11 # --- Load data ---
# ---> 12 df = pd.read_csv('../data/crop_data.csv')
#      13
#      14 # --- Set a clean visual style for all plots ---
#      15 sns.set_style("whitegrid")         # adds light grid to plots
#
# ...

# %%
# ============================================
# CROP RECOMMENDATION SYSTEM
# Phase 5 — Exploratory Data Analysis (EDA)
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt    # base plotting library
import seaborn as sns              # beautiful statistical plots

# --- Load data ---
df = pd.read_csv('../data/crop_data.csv')

# --- Set a clean visual style for all plots ---
sns.set_style("whitegrid")         # adds light grid to plots
plt.rcParams['figure.figsize'] = (10, 6)  # default figure size

print("Libraries loaded and dataset ready!")
print("Shape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 12
#       8 import matplotlib.pyplot as plt    # base plotting library
#       9 import seaborn as sns              # beautiful statistical plots
#      10
#      11 # --- Load data ---
# ---> 12 df = pd.read_csv('../data/crop_data.csv')
#      13
#      14 # --- Set a clean visual style for all plots ---
#      15 sns.set_style("whitegrid")         # adds light grid to plots
#
# ...

# %%
import os

# This prints the current working directory
# (where Python is looking for files FROM)
print("Current directory:", os.getcwd())

# This lists all files in the current directory
print("\nFiles here:", os.listdir())
# Out:
# Current directory: C:\Users\kayan\Desktop\crop-recommendation-system
#
# Files here: ['.git', '.gitignore', '.ipynb_checkpoints', '.vscode', 'data', 'exploration.ipynb', 'models', 'notebooks', 'README.md', 'src']

# %%
# Go one level up then into data/
df = pd.read_csv('../data/crop_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Go one level up then into data/
# ----> 2 df = pd.read_csv('../data/crop_data.csv')
#
# File ~\.conda\envs\crop-env\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...
